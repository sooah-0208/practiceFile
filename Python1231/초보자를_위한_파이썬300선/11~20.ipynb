# %%
삼성전자= 50000
총평가금액= 삼성전자*10
print(총평가금액)
# Out:
# 500000

# %%
시가총액=29800000
현재가 = 50000
PER= 15.79
print(type(시가총액))
print(type(현재가))
print(type(PER))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'float'>

# %%
s = "hello"
t = "python"
print(s+"!",t)
# Out:
# hello! python

# %%
a="132"
print(type(a))
# Out:
# <class 'str'>

# %%
num_str="720"
print(int(num_str))
# Out:
# 720

# %%
num=100
str_num=str(num)
print(str_num, type(str_num))
# Out:
# 100 <class 'str'>

# %%
a="19.75"
a= float(a)
print(a, type(a))
# Out:
# 19.75 <class 'float'>

# %%
year = "2020"
year=int(year)
print(year-3)
print(year-2)
print(year-1)
# Out:
# 2017
# 2018
# 2019

# %%
price = 48584
month=36
print(price*month)
# Out:
# 1749024
