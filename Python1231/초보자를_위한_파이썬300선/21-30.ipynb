# %%
letters = 'python'
print(letters[0],letters[2])
# Out:
# p t

# %%
license_plate = "24가 2210"
print(license_plate[-4:])
# Out:
# 2210

# %%
string = "홀짝홀짝홀짝"
print(string[::2])
# Out:
# 홀홀홀

# %%
string = "PYTHON"
print(string[::-1])
# Out:
# NOHTYP

# %%
phone_number = "010-1111-2222"
number=phone_number.replace("-"," ")
print(number)
# Out:
# 010 1111 2222

# %%
number=phone_number.replace("-","")
print(number)
# Out:
# 01011112222

# %%
url = "http://sharebook.kr"
url_kr=url.split('.')
print(url_kr[1])
# Out:
# kr

# %%
string = 'abcdfe2a354a32a'
string=string.replace('a',"A") #문자열은 변형 불가한 자료형이기 때문에 덮어씌워줘야함
print(string)
# Out:
# Abcdfe2A354A32A
