# %%
ticker = "btc_krw"
print(ticker.upper())
ticker = "BTC_KRW"
print(ticker.lower())
# Out:
# BTC_KRW
# btc_krw

# %%
a = "hello"
b= a.capitalize()
print(b)
# Out:
# Hello

# %%
file_name = "보고서.xlsx"
file_name.endswith(("xlsx","xls"))
# Out:
# True

# %%
file_name = "2020_보고서.xlsx"
file_name.startswith("2020")
# Out:
# True

# %%
a = "hello world"

b= a.split(' ')
print(b)
# Out:
# ['hello', 'world']

# %%
ticker = "btc_krw"
print(ticker.split('_'))
# Out:
# ['btc', 'krw']

# %%
data = "039490     "
a = data.rstrip()
print(a)

late = "     1234"
b = late.lstrip()
print(b)
# Out:
# 039490
# 1234
