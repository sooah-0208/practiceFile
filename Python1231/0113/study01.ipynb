# %%
import this

# %% [markdown]
# ### 출력 (`print`)

# %%
print(type(12345))
# Out:
# <class 'int'>

# %%
print(type("Hi guys"))
# Out:
# <class 'str'>

# %%
print("문자" * 10)
# Out:
# 문자문자문자문자문자문자문자문자문자문자

# %%
print(type(True))
# Out:
# <class 'bool'>

# %% [markdown]
# ### 변수(Variable)

# %% [markdown]
# 알파벳(대소문자), 한글 가능(한글은 비추), 예약어 변수명으로 사용 불가

# %%
a = 1

# %%
A = 2

# %%
a_b = 3

# %%
aA = 1

# %% [markdown]
# ## 데이터 타입(자료형)

# %% [markdown]
# ### 숫자형
# int: 정수
# float: 실수(소수점)

# %%
a=1
print(a)
a
type(a)
# Out:
# 1
# int

# %%
b = 1.0
b
type(b)
# Out:
# float

# %%
del b

# %%
b=1.0

# %%
a == b
# Out:
# True

# %%
type(a) == type(b)
# Out:
# False

# %% [markdown]
# ### 문자열

# %%
c = '안녕'
type(c)
c
# Out:
# '안녕'

# %%
d = '''긴 문장입니다
그쵸?
맞져?
얘는 줄바꿈을 위해 사용해요'''
type(d)
d
# Out:
# '긴 문장입니다\n그쵸?\n맞져?\n얘는 줄바꿈을 위해 사용해요'

# %% [markdown]
# ### None타입
#
# null, undefined가 python에서는 None임

# %%
for a in [1,2,3]:
    print(a)
# Out:
# 1
# 2
# 3

# %%
a = [1,2]
if len(a) < 4:
    print("a는 4보다 적은 수를 가짐")
# Out:
# a는 4보다 적은 수를 가짐

# %%
#주석
# js에서는 //이었죠? 그게 여기선 #임
a = [1,2]
if len(a) < 4:   #js의 .lenght = len()  <-이런식으로 씁니다
    print("a는 4보다 적은 수를 가짐")
# Out:
# a는 4보다 적은 수를 가짐
